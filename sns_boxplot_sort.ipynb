# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import gridspec
sns.set(style="whitegrid", color_codes=True)
# %matplotlib inline

# %%
filename = '/Users/Ania/Documents/nyc_subway_weather.csv'
subway_df = pd.read_csv(filename)

# %%
grouped = subway_df.groupby(subway_df.conds)
subway_df.ENTRIESn_hourly.groupby(subway_df.conds).median().sort_values()
# Out:
# conds
# Mist                  69.5
# Fog                  202.0
# Rain                 405.0
# Partly Cloudy        695.0
# Heavy Rain           803.0
# Mostly Cloudy        834.0
# Overcast             849.0
# Scattered Clouds     925.0
# Light Drizzle        927.0
# Clear                998.5
# Light Rain          1240.0
# Haze                1258.0
# Name: ENTRIESn_hourly, dtype: float64

# %%
order = subway_df.ENTRIESn_hourly.groupby(subway_df.conds).median().sort_values().index.values
#order

# %%
fig = plt.figure(figsize=(15, 7)) 
sns.despine(left = True)
g0 = sns.boxplot(subway_df.ENTRIESn_hourly, groupby = subway_df.conds,  data=subway_df, palette = "Set2", order = order )
g0.set(yscale = 'symlog')
g0.set_xticklabels(order,rotation=55, fontsize = 12)
g0.set_xlabel('conds', fontdict={'fontsize' : 14})
g0.set_ylabel('ENTRIESn_hourly', fontdict={'fontsize' : 14})
fig.suptitle('Hourly entries at various weather conditions', fontdict={'fontsize' : 16})
